# %%
import numpy as np

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
from sklearn.datasets.samples_generator import make_circles

# %%
X, y = make_circles(n_samples=1000,
                   noise=0.1,
                   factor=0.2,
                   random_state=0)

# %%
X.shape
# Out:
# (1000, 2)

# %%
y.shape
# Out:
# (1000,)

# %%
plt.figure(figsize=(5,5))
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title('Blue circles and Red crosses')
# Out:
# Text(0.5,1,'Blue circles and Red crosses')

# %%
from keras.models import Sequential 
from keras.layers import Dense 
from keras.optimizers import SGD
# Out:
# /home/qinritukou/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(Dense(4, input_shape=(2, ), activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 4)                 12
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 17
# Trainable params: 17
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(SGD(lr=0.5), 'binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=20)
# Out:
# Epoch 1/20
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.6546 - acc: 0.6540
# Epoch 2/20
# 1000/1000 [==============================] - 0s 81us/step - loss: 0.5565 - acc: 0.8200
# Epoch 3/20
# 1000/1000 [==============================] - 0s 72us/step - loss: 0.4621 - acc: 0.8630
# Epoch 4/20
# 1000/1000 [==============================] - 0s 68us/step - loss: 0.4012 - acc: 0.8690
# Epoch 5/20
# 1000/1000 [==============================] - 0s 70us/step - loss: 0.3567 - acc: 0.8790
# Epoch 6/20
# 1000/1000 [==============================] - 0s 66us/step - loss: 0.3057 - acc: 0.8930
# Epoch 7/20
# 1000/1000 [==============================] - 0s 71us/step - loss: 0.2355 - acc: 0.9320
# Epoch 8/20
# 1000/1000 [==============================] - 0s 67us/step - loss: 0.1744 - acc: 0.9910
# Epoch 9/20
# 1000/1000 [==============================] - 0s 71us/step - loss: 0.1348 - acc: 0.9990
# Epoch 10/20
# 1000/1000 [==============================] - 0s 72us/step - loss: 0.1077 - acc: 1.0000
# Epoch 11/20
# 1000/1000 [==============================] - 0s 68us/step - loss: 0.0888 - acc: 1.0000
# Epoch 12/20
# 1000/1000 [==============================] - 0s 71us/step - loss: 0.0749 - acc: 1.0000
# Epoch 13/20
# 1000/1000 [==============================] - 0s 71us/step - loss: 0.0643 - acc: 1.0000
# Epoch 14/20
# 1000/1000 [==============================] - 0s 70us/step - loss: 0.0564 - acc: 1.0000
# Epoch 15/20
# 1000/1000 [==============================] - 0s 67us/step - loss: 0.0500 - acc: 1.0000
# Epoch 16/20
# 1000/1000 [==============================] - 0s 66us/step - loss: 0.0451 - acc: 1.0000
# Epoch 17/20
# 1000/1000 [==============================] - 0s 66us/step - loss: 0.0409 - acc: 1.0000
# Epoch 18/20
# 1000/1000 [==============================] - 0s 69us/step - loss: 0.0376 - acc: 1.0000
# Epoch 19/20
# 1000/1000 [==============================] - 0s 65us/step - loss: 0.0346 - acc: 1.0000
# Epoch 20/20
# 1000/1000 [==============================] - 0s 66us/step - loss: 0.0322 - acc: 1.0000

# %%
hticks = np.linspace(-1.5, 1.5, 101)
vticks = np.linspace(-1.5, 1.5, 101)
aa, bb = np.meshgrid(hticks, vticks)
ab = np.c_[aa.ravel(), bb.ravel()]
c = model.predict(ab)
cc = c.reshape(aa.shape)

# %%
plt.figure(figsize=(5, 5))
plt.contourf(aa, bb, cc, cmap='bwr', alpha=0.2)
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'ob', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5,1,'Blue circles and Red crosses')
